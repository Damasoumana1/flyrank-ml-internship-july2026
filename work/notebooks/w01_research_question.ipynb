# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Damasoumana1/flyrank-ml-internship-july2026/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# **Lane:** Refresh / Content Opportunity Scoring
#
# I chose this lane because it focuses on using machine learning to prioritize content improvement opportunities based on observable search and engagement signals. Rather than predicting guaranteed outcomes, this project supports evidence-based decision-making by helping content teams identify webpages that deserve review first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Research Question**
#
# How can machine learning help prioritize webpages that should be reviewed for content improvement based on observable search and engagement signals?
#
# **Decision**
#
# A content team needs to decide which webpages should be reviewed first for refresh, optimization, monitoring, or further investigation.
#
# **Action**
#
# The team can prioritize review, content updates, optimization, or monitoring for the highest-ranked pages.
#
# **Cost of a Wrong Recommendation**
#
# A wrong recommendation may cause teams to spend time improving low-impact pages while overlooking pages with greater potential for visibility or engagement improvements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains **30,000 webpages** described by **44 features**.
#
# Approximately **54.2%** of the webpages are labeled as declining, making content prioritization a meaningful decision problem.
#
# These observations suggest that machine learning can help identify pages that deserve review based on observable search and engagement signals.

# %%
import os
import subprocess

if not os.path.isdir("flyrank-ml-internship-starter"):
    subprocess.run([
        "git", "clone", "--depth", "1",
        "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
    ])

os.chdir("flyrank-ml-internship-starter")

print(os.getcwd())
# Out:
# /content/flyrank-ml-internship-starter

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Declining pages:", round((df["trend_direction"]=="down").mean()*100,1), "%")
# Out:
# Rows: 30000
# Columns: 44
# Declining pages: 54.2 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project is designed to support content prioritization rather than predict guaranteed outcomes.
#
# A high score identifies webpages that deserve review based on available evidence, but it does not prove that updating a page will improve its future performance.
#
# The results should be interpreted as decision-support rather than causal proof, and human review remains essential before any action is taken.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x ] Every section above is filled — markdown thinking AND the code that backs it
# - [ x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ x] No client names, URLs, or private queries anywhere
# - [x ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
